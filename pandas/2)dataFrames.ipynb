# %%
import numpy as np
import pandas as pd

# %% [markdown]
# **CREATEING A DATA FRAME**

# %%
data = {
'Name': ['John', 'Anna', 'Peter', 'Linda'],
'Age': [28, 34, 29, 42],
'City': ['New York', 'Paris', 'Berlin', 'London'],
'Salary': [65000, 70000, 62000, 85000]
}

# %%
df = pd.DataFrame(data)
df
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
data_list = [
['John', 28, 'New York', 65000],
['Anna', 34, 'Paris', 70000],
['Peter', 29, 'Berlin', 62000],
['Linda', 42, 'London', 85000]
]
df2 = pd.DataFrame(data_list)

# %%
df2
# Out:
#        0   1         2      3
# 0   John  28  New York  65000
# 1   Anna  34     Paris  70000
# 2  Peter  29    Berlin  62000
# 3  Linda  42    London  85000

# %%
#create datafreme using list colum set manually 
data_list = [
['John', 28, 'New York', 65000],
['Anna', 34, 'Paris', 70000],
['Peter', 29, 'Berlin', 62000],
['Linda', 42, 'London', 85000]
]
column = ["Name","Age","City","Salary"]
df2 = pd.DataFrame(data_list,columns=column)

# %%
df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %% [markdown]
# **Selection  and indexing of columns**

# %%
 df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
#select name columns
df2["Name"]
# Out:
# 0     John
# 1     Anna
# 2    Peter
# 3    Linda
# Name: Name, dtype: object

# %%
#select name city
df2["City"]
# Out:
# 0    New York
# 1       Paris
# 2      Berlin
# 3      London
# Name: City, dtype: object

# %%
# select 2 column name and city 
df2[["Name","City"]]
# Out:
#     Name      City
# 0   John  New York
# 1   Anna     Paris
# 2  Peter    Berlin
# 3  Linda    London

# %% [markdown]
# **CREARING A NEW COLUMN**

# %%
df2["Degination"]=["Docter","Engineering","doctro","worker"]

# %%
df2
# Out:
#     Name  Age      City  Salary   Degination
# 0   John   28  New York   65000       Docter
# 1   Anna   34     Paris   70000  Engineering
# 2  Peter   29    Berlin   62000       doctro
# 3  Linda   42    London   85000       worker

# %% [markdown]
# Removing column

# %%
#delete a coloumn form data Frame
df2.drop("Degination", axis = 1,inplace = True)

# %%
df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
#delete multiple column delete 
df2.drop(["City","Salary"], axis = 1)
# Out:
#     Name  Age
# 0   John   28
# 1   Anna   34
# 2  Peter   29
# 3  Linda   42

# %% [markdown]
# Selection a rows

# %%
df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df2.loc[0]
# Out:
# Name          John
# Age             28
# City      New York
# Salary       65000
# Name: 0, dtype: object

# %%
#select multiple rows 
df2.loc[[0,1]] #loc menas location
# Out:
#    Name  Age      City  Salary
# 0  John   28  New York   65000
# 1  Anna   34     Paris   70000

# %% [markdown]
# Selectin Subsets of Rows and Column

# %%
df2.loc[[0,1]][["City","Salary"]]
# Out:
#        City  Salary
# 0  New York   65000
# 1     Paris   70000

# %%
df2.loc[[0,1]][["Name","Age"]]
# Out:
#    Name  Age
# 0  John   28
# 1  Anna   34

# %% [markdown]
# **Condition Selection**

# %%
# I want to see those people whose age is above 30
df2[df2["Age"]>30]
# Out:
#     Name  Age    City  Salary
# 1   Anna   34   Paris   70000
# 3  Linda   42  London   85000

# %%
# I want to see those people  whose age is above 30 and city must be paris
df2[(df2["Age"] > 30) & (df2["City"] == "Paris")]
# Out:
#    Name  Age   City  Salary
# 1  Anna   34  Paris   70000
