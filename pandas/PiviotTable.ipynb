# %%
import numpy as np
import pandas as pd

# %% [markdown]
# **Pivot Table**

# %%
data = {
'Date': pd.date_range('2023-01-01', periods=20),
'Product': ['A', 'B', 'C', 'D'] * 5,
'Region': ['East', 'West', 'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West',
'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West', 'North', 'South'],
'Sales': np. random. randint(100, 1000, 20),
'Units': np. random. randint(10, 100, 20),
'Rep': ['John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary',
'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice' ]
}
df = pd. DataFrame(data)

df ['Month' ] = df ['Date' ] . dt.month_name ()
df['Quarter'] = 'Q' + df ['Date'].dt.quarter.astype(str)

# %%
df
# Out:
#          Date Product Region  Sales  Units    Rep    Month Quarter
# 0  2023-01-01       A   East    388     29   John  January      Q1
# 1  2023-01-02       B   West    553     48   Mary  January      Q1
# 2  2023-01-03       C  North    432     56    Bob  January      Q1
# 3  2023-01-04       D  South    262     91  Alice  January      Q1
# 4  2023-01-05       A   East    577     66   John  January      Q1
# 5  2023-01-06       B   West    890     60   Mary  January      Q1
# 6  2023-01-07       C  North    944     37    Bob  January      Q1
# 7  2023-01-08       D  South    285     63  Alice  January      Q1
# 8  2023-01-09       A   East    350     43   John  January      Q1
# 9  2023-01-10       B   West    179     64   Mary  January      Q1
# 10 2023-01-11       C  North    134     99    Bob  January      Q1
# 11 2023-01-12       D  South    991     18  Alice  January      Q1
# 12 2023-01-13       A   East    402     66   John  January      Q1
# 13 2023-01-14       B   West    307     89   Mary  January      Q1
# 14 2023-01-15       C  North    739     83    Bob  January      Q1
# 15 2023-01-16       D  South    259     44  Alice  January      Q1
# 16 2023-01-17       A   East    343     17   John  January      Q1
# 17 2023-01-18       B   West    423     32   Mary  January      Q1
# 18 2023-01-19       C  North    135     80    Bob  January      Q1
# 19 2023-01-20       D  South    229     89  Alice  January      Q1

# %%
pd.pivot_table(df,values="Sales",index ="Region",columns="Product")
# Out:
# Product      A      B      C      D
# Region
# East     412.0    NaN    NaN    NaN
# North      NaN    NaN  476.8    NaN
# South      NaN    NaN    NaN  405.2
# West       NaN  470.4    NaN    NaN

# %%
pivot2 = pd.pivot_table(df,values=["Sales","Units"],index ="Region",columns="Product")
pivot2
# Out:
#          Sales                      Units
# Product      A      B      C      D     A     B     C     D
# Region
# East     412.0    NaN    NaN    NaN  44.2   NaN   NaN   NaN
# North      NaN    NaN  476.8    NaN   NaN   NaN  71.0   NaN
# South      NaN    NaN    NaN  405.2   NaN   NaN   NaN  61.0
# West       NaN  470.4    NaN    NaN   NaN  58.6   NaN   NaN

# %% [raw]
# **values: Columns to aggregate.
# index: Columns to use as the new row index.
# columns: Columns to use as the new column headers.
# aggfunc: Aggregation functions like mean, sum, count etc. By default it is mean.
# fill_value: Value to replace missing data.
# margins: Whether to add totals, default is false.
# dropna: Whether to exclude missing values from the DataFrame, default is True.**

# %% [markdown]
# **Cross Tabs**

# %%
pd.crosstab(df['Region'],df['Product'])
# Out:
# Product  A  B  C  D
# Region
# East     5  0  0  0
# North    0  0  5  0
# South    0  0  0  5
# West     0  5  0  0

# %% [markdown]
# **Example2** Let us take an example if we take a data set of Handedness of people which includes peoples nationality, sex, age, and name. Suppose if we want to analyze the relationship between nationality and handedness of the peoples. Crosstab gives you the relationship between them.
