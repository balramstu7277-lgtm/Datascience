# %%
import numpy as np
import pandas as pd

# %% [markdown]
# **Gropu By**

# %%
data = {
'Category': ['A', 'B', 'A', 'B', 'A', 'B', 'A', 'B'],
'Store': ['S1', 'S1', 'S2', 'S2', 'S1', 'S2', 'S2', 'S1'],
'Sales': [100, 200, 150, 250, 120, 180, 200, 300],
'Quantity': [10, 15, 12, 18, 8, 20, 15, 25],
'Date': pd.date_range('2023-01-01', periods=8)
}
df = pd.DataFrame(data)

# %%
df
# Out:
#   Category Store  Sales  Quantity       Date
# 0        A    S1    100        10 2023-01-01
# 1        B    S1    200        15 2023-01-02
# 2        A    S2    150        12 2023-01-03
# 3        B    S2    250        18 2023-01-04
# 4        A    S1    120         8 2023-01-05
# 5        B    S2    180        20 2023-01-06
# 6        A    S2    200        15 2023-01-07
# 7        B    S1    300        25 2023-01-08

# %%
#Group By category and calculate the sum of sales
cat = df.groupby('Category')['Sales']
cat
for i , v in cat:
    print(i)
    print(v)
# Out:
# A
# 0    100
# 2    150
# 4    120
# 6    200
# Name: Sales, dtype: int64
# B
# 1    200
# 3    250
# 5    180
# 7    300
# Name: Sales, dtype: int64

# %%
cat = df.groupby('Category')['Sales'].sum()
cat
# Out:
# Category
# A    570
# B    930
# Name: Sales, dtype: int64

# %%
#groupby store and calculate  the sum of sales
sto = df.groupby('Store')['Sales'].sum()
sto
# Out:
# Store
# S1    720
# S2    780
# Name: Sales, dtype: int64

# %%
#group by muiltipale columns
#group catagory  and store  
mul =df.groupby(['Category','Store'])['Sales'].sum()
mul
# Out:
# Category  Store
# A         S1       220
#           S2       350
# B         S1       500
#           S2       430
# Name: Sales, dtype: int64

# %% [markdown]
# **Aggregation**

# %%
df['Sales'].mean()
# Out:
# np.float64(187.5)

# %%
df['Sales'].agg(['sum' , 'mean' ,'min' , 'max' , 'std' ,'median'])
# Out:
# sum       1500.000000
# mean       187.500000
# min        100.000000
# max        300.000000
# std         66.062741
# median     190.000000
# Name: Sales, dtype: float64
